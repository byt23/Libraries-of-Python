# %%
import numpy as np

# %%
my_list = [1, 2, 3, 4, 5]

# %%
type(my_list)
# Out:
# list

# %%
np.array(my_list)
# Out:
# array([1, 2, 3, 4, 5])

# %%
my_numpy_array = np.array(my_list)

# %%
type(my_numpy_array)
# Out:
# numpy.ndarray

# %%
my_numpy_array.max()
# Out:
# np.int64(5)

# %%
print(my_numpy_array.max())
# Out:
# 5

# %%
print(my_numpy_array.mean())
# Out:
# 3.0

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.random.random(5)
# Out:
# array([0.00622006, 0.45783901, 0.67689858, 0.69363744, 0.94730215])

# %% [markdown]
# Array Arithmetic

# %%
my_list1 = [1,2]

# %%
my_list2 = [2,3]

# %%
my_list1 + my_list2
# Out:
# [1, 2, 2, 3]

# %%
my_numpy_array1 = np.array(my_list1)

# %%
my_numpy_array2 = np.array(my_list2)

# %%
my_numpy_array1 + my_numpy_array2
# Out:
# array([3, 5])

# %%
my_numpy_array1 - my_numpy_array2
# Out:
# array([-1, -1])

# %%
my_numpy_array1 * my_numpy_array2
# Out:
# array([2, 6])

# %%
my_numpy_array1 / my_numpy_array2
# Out:
# array([0.5       , 0.66666667])

# %%
my_numpy_array1 * 5
# Out:
# array([ 5, 10])

# %%
my_list1 * 5
# Out:
# [1, 2, 1, 2, 1, 2, 1, 2, 1, 2]

# %%
other_array = np.array([10,20,30,40,50])

# %%
other_array.min()
# Out:
# np.int64(10)

# %%
other_array.sum()
# Out:
# np.int64(150)

# %%
my_numpy_array1
# Out:
# array([1, 2])

# %%
other_array
# Out:
# array([10, 20, 30, 40, 50])
