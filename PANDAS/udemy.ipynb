# %% [markdown]
# From Atıl Samancıoğlu's Course : Data Science and Machine Learning
#
# -> Pandas Library 🐼

# %% [markdown]
# Jay Alammar Web Link : https://jalammar.github.io/gentle-visual-intro-to-data-analysis-python-pandas/

# %%
import numpy as np
import pandas as pd

# %%
grades = {"Atıl" : 50 , "James" : 60, "Lars" : 30}

# %%
pd.Series(grades)
# Out:
# Atıl     50
# James    60
# Lars     30
# dtype: int64

# %%
names = ["Atıl", "James", "Lars"]
grades = [50, 60, 30]

# %%
pd.Series(names)
# Out:
# 0     Atıl
# 1    James
# 2     Lars
# dtype: object

# %%
pd.Series(grades)
# Out:
# 0    50
# 1    60
# 2    30
# dtype: int64

# %%
pd.Series(grades, names)
# Out:
# Atıl     50
# James    60
# Lars     30
# dtype: int64

# %%
pd.Series(data = grades, index = names)
# Out:
# Atıl     50
# James    60
# Lars     30
# dtype: int64

# %% [markdown]
# Pandas With NumPy

# %%
numpy_array = np.array([50, 40, 30, 20])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    40
# 2    30
# 3    20
# dtype: int64

# %% [markdown]
# Arithmetic

# %%
contest_result = pd.Series(data = [10,5,100], index = ["Atıl", "James", "Lars"])
contest_result2 = pd.Series(data = [20,50,10], index = ["Atıl", "James", "Lars"])

# %%
contest_result
# Out:
# Atıl      10
# James      5
# Lars     100
# dtype: int64

# %%
contest_result["Atıl"]
# Out:
# np.int64(10)

# %%
contest_result2["James"]
# Out:
# np.int64(50)

# %%
final_result = contest_result + contest_result2
final_result
# Out:
# Atıl      30
# James     55
# Lars     110
# dtype: int64

# %%
contest_result - contest_result2
# Out:
# Atıl    -10
# James   -45
# Lars     90
# dtype: int64

# %%
contest_result * contest_result2
# Out:
# Atıl      200
# James     250
# Lars     1000
# dtype: int64

# %%
contest_result / contest_result2
# Out:
# Atıl      0.5
# James     0.1
# Lars     10.0
# dtype: float64

# %%
contest_result ** contest_result2
# Out:
# Atıl     7766279631452241920
# James   -6776596920136667815
# Lars     7766279631452241920
# dtype: int64

# %%
contest_result // contest_result2
# Out:
# Atıl      0
# James     0
# Lars     10
# dtype: int64

# %%
different_series = pd.Series([20,30,40,50],["a","b","c","d"])

# %%
different_series2 = pd.Series([10,5,3,1],["a","c","f","g"])

# %%
different_series + different_series2
# Out:
# a    30.0
# b     NaN
# c    45.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64

# %% [markdown]
# Introduction to DataFrame

# %%
import numpy as np
import pandas as pd

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[-0.86204892, -0.61072325, -0.3602186 ],
#        [ 0.41981636, -1.15224449,  0.82797846],
#        [ 1.47112306, -1.94737299, -1.34442586],
#        [-1.99175772,  0.82045374,  0.05563311]])

# %%
data_frame = pd.DataFrame(data)
data_frame
# Out:
#           0         1         2
# 0 -0.862049 -0.610723 -0.360219
# 1  0.419816 -1.152244  0.827978
# 2  1.471123 -1.947373 -1.344426
# 3 -1.991758  0.820454  0.055633

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
data_frame[0]
# Out:
# 0   -0.862049
# 1    0.419816
# 2    1.471123
# 3   -1.991758
# Name: 0, dtype: float64

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
new_df = pd.DataFrame(data, index = ["Atil","Zeynep","Atlas","Mehmet"], columns = ["Salary", "Age", "Seniority"])
new_df
# Out:
#           Salary       Age  Seniority
# Atil   -0.862049 -0.610723  -0.360219
# Zeynep  0.419816 -1.152244   0.827978
# Atlas   1.471123 -1.947373  -1.344426
# Mehmet -1.991758  0.820454   0.055633

# %%
new_df["Salary"]
# Out:
# Atil     -0.862049
# Zeynep    0.419816
# Atlas     1.471123
# Mehmet   -1.991758
# Name: Salary, dtype: float64

# %%
new_df["Age"]
# Out:
# Atil     -0.610723
# Zeynep   -1.152244
# Atlas    -1.947373
# Mehmet    0.820454
# Name: Age, dtype: float64

# %%
new_df[["Age","Salary"]]
# Out:
#              Age    Salary
# Atil   -0.610723 -0.862049
# Zeynep -1.152244  0.419816
# Atlas  -1.947373  1.471123
# Mehmet  0.820454 -1.991758

# %%
new_df.loc["Atil"]
# Out:
# Salary      -0.862049
# Age         -0.610723
# Seniority   -0.360219
# Name: Atil, dtype: float64

# %%
new_df.iloc[0]
# Out:
# Salary      -0.862049
# Age         -0.610723
# Seniority   -0.360219
# Name: Atil, dtype: float64

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil   -0.862049 -0.610723  -0.360219
# Zeynep  0.419816 -1.152244   0.827978
# Atlas   1.471123 -1.947373  -1.344426
# Mehmet -1.991758  0.820454   0.055633

# %%
new_df.iloc[:,2]
# Out:
# Atil     -0.360219
# Zeynep    0.827978
# Atlas    -1.344426
# Mehmet    0.055633
# Name: Seniority, dtype: float64

# %%
new_df["Age"]
# Out:
# Atil     -0.610723
# Zeynep   -1.152244
# Atlas    -1.947373
# Mehmet    0.820454
# Name: Age, dtype: float64

# %%
new_df["Extra"] = 10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Atil   -0.862049 -0.610723  -0.360219     10
# Zeynep  0.419816 -1.152244   0.827978     10
# Atlas   1.471123 -1.947373  -1.344426     10
# Mehmet -1.991758  0.820454   0.055633     10

# %%
new_df.drop("Extra", axis = 1)
# Out:
#           Salary       Age  Seniority
# Atil   -0.862049 -0.610723  -0.360219
# Zeynep  0.419816 -1.152244   0.827978
# Atlas   1.471123 -1.947373  -1.344426
# Mehmet -1.991758  0.820454   0.055633

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Atil   -0.862049 -0.610723  -0.360219     10
# Zeynep  0.419816 -1.152244   0.827978     10
# Atlas   1.471123 -1.947373  -1.344426     10
# Mehmet -1.991758  0.820454   0.055633     10

# %%
new_df = new_df.drop("Extra" , axis = 1)

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil   -0.862049 -0.610723  -0.360219
# Zeynep  0.419816 -1.152244   0.827978
# Atlas   1.471123 -1.947373  -1.344426
# Mehmet -1.991758  0.820454   0.055633

# %%
new_df["Extra"] = 10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Atil   -0.862049 -0.610723  -0.360219     10
# Zeynep  0.419816 -1.152244   0.827978     10
# Atlas   1.471123 -1.947373  -1.344426     10
# Mehmet -1.991758  0.820454   0.055633     10

# %%
new_df.drop("Extra", axis = 1 , inplace = True)

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil   -0.862049 -0.610723  -0.360219
# Zeynep  0.419816 -1.152244   0.827978
# Atlas   1.471123 -1.947373  -1.344426
# Mehmet -1.991758  0.820454   0.055633

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil   -0.862049 -0.610723  -0.360219
# Zeynep  0.419816 -1.152244   0.827978
# Atlas   1.471123 -1.947373  -1.344426
# Mehmet -1.991758  0.820454   0.055633

# %%
new_df.drop("Mehmet", axis = 0)
# Out:
#           Salary       Age  Seniority
# Atil   -0.862049 -0.610723  -0.360219
# Zeynep  0.419816 -1.152244   0.827978
# Atlas   1.471123 -1.947373  -1.344426

# %%
new_df.loc["Atlas"]
# Out:
# Salary       1.471123
# Age         -1.947373
# Seniority   -1.344426
# Name: Atlas, dtype: float64

# %%
new_df.loc["Atlas"]["Salary"]
# Out:
# np.float64(1.471123061678557)

# %%
new_df.loc["Atlas","Salary"]
# Out:
# np.float64(1.471123061678557)

# %%
new_df.loc["Atlas","Salary"] = 100

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil     -0.862049 -0.610723  -0.360219
# Zeynep    0.419816 -1.152244   0.827978
# Atlas   100.000000 -1.947373  -1.344426
# Mehmet   -1.991758  0.820454   0.055633

# %%
new_df > 0
# Out:
#         Salary    Age  Seniority
# Atil     False  False      False
# Zeynep    True  False       True
# Atlas     True  False      False
# Mehmet   False   True       True

# %%
boolean_frame = new_df > 0

# %%
boolean_frame
# Out:
#         Salary    Age  Seniority
# Atil     False  False      False
# Zeynep    True  False       True
# Atlas     True  False      False
# Mehmet   False   True       True

# %%
new_df[boolean_frame]
# Out:
#             Salary       Age  Seniority
# Atil           NaN       NaN        NaN
# Zeynep    0.419816       NaN   0.827978
# Atlas   100.000000       NaN        NaN
# Mehmet         NaN  0.820454   0.055633

# %%
new_df[new_df > 0]
# Out:
#             Salary       Age  Seniority
# Atil           NaN       NaN        NaN
# Zeynep    0.419816       NaN   0.827978
# Atlas   100.000000       NaN        NaN
# Mehmet         NaN  0.820454   0.055633

# %%
new_df[new_df["Salary"] > 1]
# Out:
#        Salary       Age  Seniority
# Atlas   100.0 -1.947373  -1.344426

# %%
new_df[new_df["Age"] > 1]
# Out:
# Empty DataFrame
# Columns: [Salary, Age, Seniority]
# Index: []

# %% [markdown]
# DataFrame Index

# %%
new_df.reset_index()
# Out:
#     index      Salary       Age  Seniority
# 0    Atil   -0.862049 -0.610723  -0.360219
# 1  Zeynep    0.419816 -1.152244   0.827978
# 2   Atlas  100.000000 -1.947373  -1.344426
# 3  Mehmet   -1.991758  0.820454   0.055633

# %%
reset_frame = new_df.reset_index()

# %%
reset_frame
# Out:
#     index      Salary       Age  Seniority
# 0    Atil   -0.862049 -0.610723  -0.360219
# 1  Zeynep    0.419816 -1.152244   0.827978
# 2   Atlas  100.000000 -1.947373  -1.344426
# 3  Mehmet   -1.991758  0.820454   0.055633

# %%
new_indices = ["Ati","Zey","Atl","Meh"]

# %%
new_df["NewIndex"] = new_indices

# %%
new_df
# Out:
#             Salary       Age  Seniority NewIndex
# Atil     -0.862049 -0.610723  -0.360219      Ati
# Zeynep    0.419816 -1.152244   0.827978      Zey
# Atlas   100.000000 -1.947373  -1.344426      Atl
# Mehmet   -1.991758  0.820454   0.055633      Meh

# %%
new_df.set_index("NewIndex", inplace = True)

# %%
new_df
# Out:
#               Salary       Age  Seniority
# NewIndex
# Ati        -0.862049 -0.610723  -0.360219
# Zey         0.419816 -1.152244   0.827978
# Atl       100.000000 -1.947373  -1.344426
# Meh        -1.991758  0.820454   0.055633

# %% [markdown]
# Multi Index

# %%
first_index = ["Simpson","Simpson","Simpson","South Park", "South Park","South Park"]

# %%
inner_index = ["Homer","Bart","Marge","Cartman","Kenny","Kyle"]

# %%
zipped_index = list(zip(first_index,inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index = pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(sample_values, index = zipped_index , columns = ["Age", "Salary"] )

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Homer    1.0     1.0
#            Bart     1.0     1.0
#            Marge    1.0     1.0
# South Park Cartman  1.0     1.0
#            Kenny    1.0     1.0
#            Kyle     1.0     1.0

# %% [markdown]
# This file ended, keep going with part 2...
